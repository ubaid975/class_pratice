# %%
import pandas as pd

# %%
data=pd.read_csv('kLnTOz.csv')

# %%
data
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
data.Status.unique()
# Out:
# array(['Active', 'Retired', 'Deceased', 'Management'], dtype=object)

# %%
active=data[data.Status=="Active"]

# %%
retired=data[data.Status=="Retired"]

# %%
Deceased=data[data.Status=="Deceased"]

# %%
Management=data[data.Status=="Management"]

# %%
Deceased
# Out:
#                             Name    Year  Group    Status  Birth Date  \
# 10           Michael P. Anderson  1995.0   15.0  Deceased  12/25/1959
# 14             Neil A. Armstrong  1962.0    2.0  Deceased    8/5/1930
# 24        Charles A. Bassett II   1963.0    3.0  Deceased  12/30/1931
# 36         Charles E. Brady Jr.   1992.0   14.0  Deceased   8/12/1951
# 42                David M. Brown  1996.0   16.0  Deceased   4/16/1956
# 46                  John S. Bull  1966.0    5.0  Deceased   9/25/1934
# 51             Fernando Caldeiro  1996.0   16.0  Deceased   6/12/1958
# 58     Manley Lanier Carter Jr.   1984.0   10.0  Deceased   8/15/1947
# 63              Roger B. Chaffee  1963.0    3.0  Deceased   2/15/1935
# 67                Kalpana Chawla  1995.0   15.0  Deceased    6/1/1961
# 70               Laurel B. Clark  1996.0   16.0  Deceased   3/10/1961
# 78           Charles Conrad Jr.   1962.0    2.0  Deceased    5/2/1930
# ...

# %%
Deceased.Gender.value_counts()
# Out:
# Gender
# Male      44
# Female     7
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
x=data[data.Gender=='Male']

# %%
y=data[data.Gender=='Female']

# %%
plt.pie()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 plt.pie()
#
# TypeError: pie() missing 1 required positional argument: 'x'

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date', 'Death Mission'],
#       dtype='object')

# %%
data[data['Space Flight (hr)']==data['Space Flight (hr)'].max()][['Name','Status','Gender']]
# Out:
#                     Name  Status Gender
# 346  Jeffrey N. Williams  Active   Male

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# Death Date             305
# Death Mission          341
# dtype: int64

# %%
del data['Death Mission']

# %%
data
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# Death Date             305
# dtype: int64

# %%
del data['Death Date']

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# dtype: int64

# %%
del data['Military Branch']

# %%
del data['Military Rank']

# %%
data.isnull().sum()
# Out:
# Name                    0
# Year                   27
# Group                  27
# Status                  0
# Birth Date              0
# Birth Place             0
# Gender                  0
# Alma Mater              1
# Undergraduate Major    22
# Graduate Major         59
# Space Flights           0
# Space Flight (hr)       0
# Space Walks             0
# Space Walks (hr)        0
# Missions               23
# dtype: int64

# %%
data.Status.unique()
# Out:
# array(['Active', 'Retired', 'Deceased', 'Management'], dtype=object)

# %%
counts=data.Status.value_counts()

# %%
labels=data.Status.unique()

# %%
Deceased=data[data['Status']=="Deceased"]

# %%
import numpy as np
a=np.array(active)
b=np.array(Retired)

# %%
plt.bar(labels,counts,width=0.6,color='m')
plt.title('Status  Bar Charts',fontsize=20,color='k')
plt.xlabel('Status',fontsize=13)
plt.ylabel('No of Counts',fontsize=13)
plt.show()

# %%
Deceased
# Out:
#                             Name    Year  Group    Status  Birth Date  \
# 10           Michael P. Anderson  1995.0   15.0  Deceased  12/25/1959
# 14             Neil A. Armstrong  1962.0    2.0  Deceased    8/5/1930
# 24        Charles A. Bassett II   1963.0    3.0  Deceased  12/30/1931
# 36         Charles E. Brady Jr.   1992.0   14.0  Deceased   8/12/1951
# 42                David M. Brown  1996.0   16.0  Deceased   4/16/1956
# 46                  John S. Bull  1966.0    5.0  Deceased   9/25/1934
# 51             Fernando Caldeiro  1996.0   16.0  Deceased   6/12/1958
# 58     Manley Lanier Carter Jr.   1984.0   10.0  Deceased   8/15/1947
# 63              Roger B. Chaffee  1963.0    3.0  Deceased   2/15/1935
# 67                Kalpana Chawla  1995.0   15.0  Deceased    6/1/1961
# 70               Laurel B. Clark  1996.0   16.0  Deceased   3/10/1961
# 78           Charles Conrad Jr.   1962.0    2.0  Deceased    5/2/1930
# ...

# %%
x=Deceased['Gender'].unique()

# %%
y=Deceased['Gender'].value_counts()

# %%
import matplotlib.style as sty
sty.use('ggplot')
plt.bar(x,y,width=0.2,color='y')
plt.title('Gender Charts',fontsize=16)
plt.xlabel('Gender',fontsize=13)
plt.ylabel('No of Counts',fontsize=13)
plt.savefig('death_male_female_pbar.jpg')

# %%
plt.pie(y,labels=x,explode=[0.2,0],colors=['m','g'],autopct='%0.f%%',shadow=True,radius=1.4,startangle=180,textprops={'fontsize':18})
plt.savefig('death_male_female_p.jpg')

plt.legend(loc=8)

plt.show()

# %%
plt.savefig('death_male_female.jpg')
